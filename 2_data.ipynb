# %%
import numpy as np 
import pandas

# %%
path = "Data & AI Learning Paths.xlsx"
data = pandas.read_excel(path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ManojKumarKarumanchi\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\ManojKumarKarumanchi\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %% [markdown]
# ### ImportError: Missing optional dependency 'openpyxl'.
# ####  Use pip or conda to install openpyxl. !pip install opeenpyxl
#
# #### Now the error is to install openpyxl library for reading all formats of excel and xml etc files

# %%
import pandas as pd

path = "Data & AI Learning Paths.xlsx"
try:            # try printing head if it works
    data = pd.read_excel(path, engine='openpyxl')
    print(data.head())
except Exception as e: # else show error
    print(f"Error: {e}")
# Out:
#    Unnamed: 0            Unnamed: 1  \
# 0         NaN  Python Learning Path
# 1         NaN                     #
# 2         NaN                     1
# 3         NaN                     2
# 4         NaN                     3
#
#                                           Unnamed: 2
# 0                                                NaN
# 1                                             Module
# 2  Introduction to Python - Training | Microsoft ...
# 3  Python for beginners - Training | Microsoft Learn
# 4      Get started with Python in Visual Studio Code

# %%
path = "Data & AI Learning Paths.xlsx"
data = pd.read_excel(path)

# %%
df = data.copy() # data copied to new variable to prevent data to be in same original condition

# %%
df1 = pd.DataFrame(df) # data converted to data frame

# %%
df1
# Out:
#     Unnamed: 0            Unnamed: 1  \
# 0          NaN  Python Learning Path
# 1          NaN                     #
# 2          NaN                     1
# 3          NaN                     2
# 4          NaN                     3
# 5          NaN                     4
# 6          NaN                     5
# 7          NaN                     6
# 8          NaN                     7
# 9          NaN                     8
# 10         NaN                     9
# 11         NaN                    10
# 12         NaN                    11
# 13         NaN                    12
# 14         NaN                    13
# 15         NaN                    14
# 16         NaN                    15
# 17         NaN                    16
# 18         NaN                    17
# 19         NaN                    18
#
#                                            Unnamed: 2
# 0                                                 NaN
# 1                                              Module
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    20
# Unnamed: 1     0
# Unnamed: 2     1
# dtype: int64

# %%
df1.isnull()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2
# 0         True       False        True
# 1         True       False       False
# 2         True       False       False
# 3         True       False       False
# 4         True       False       False
# 5         True       False       False
# 6         True       False       False
# 7         True       False       False
# 8         True       False       False
# 9         True       False       False
# 10        True       False       False
# 11        True       False       False
# 12        True       False       False
# 13        True       False       False
# 14        True       False       False
# 15        True       False       False
# 16        True       False       False
# 17        True       False       False
# 18        True       False       False
# 19        True       False       False

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
df1.dropna(axis=1)
df1
# Out:
#     Unnamed: 0            Unnamed: 1  \
# 0          NaN  Python Learning Path
# 1          NaN                     #
# 2          NaN                     1
# 3          NaN                     2
# 4          NaN                     3
# 5          NaN                     4
# 6          NaN                     5
# 7          NaN                     6
# 8          NaN                     7
# 9          NaN                     8
# 10         NaN                     9
# 11         NaN                    10
# 12         NaN                    11
# 13         NaN                    12
# 14         NaN                    13
# 15         NaN                    14
# 16         NaN                    15
# 17         NaN                    16
# 18         NaN                    17
# 19         NaN                    18
#
#                                            Unnamed: 2
# 0                                                 NaN
# 1                                              Module
# ...

# %%
dff = df1.drop(columns=['Unnamed: 0'])

# %%
dff.fillna("None")
# Out:
#               Unnamed: 1                                         Unnamed: 2
# 0   Python Learning Path                                               None
# 1                      #                                             Module
# 2                      1  Introduction to Python - Training | Microsoft ...
# 3                      2  Python for beginners - Training | Microsoft Learn
# 4                      3      Get started with Python in Visual Studio Code
# 5                      4               Create and manage projects in Python
# 6                      5                                              Numpy
# 7                      6                                             Pandas
# 8                      7                                              Scipy
# 9                      8                                      File handling
# 10                     9                                           Requests
# ...

# %%
dff.iloc[1:1] = "none"

# %%
dff.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
dff.describe()
# Out:
#                   Unnamed: 1 Unnamed: 2
# count                     20         19
# unique                    20         19
# top     Python Learning Path     Module
# freq                       1          1

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  20 non-null     object
#  1   Unnamed: 2  19 non-null     object
# dtypes: object(2)
# memory usage: 452.0+ bytes

# %%
df2 = data.copy()
df2.head()
# Out:
#    Unnamed: 0            Unnamed: 1  \
# 0         NaN  Python Learning Path
# 1         NaN                     #
# 2         NaN                     1
# 3         NaN                     2
# 4         NaN                     3
#
#                                           Unnamed: 2
# 0                                                NaN
# 1                                             Module
# 2  Introduction to Python - Training | Microsoft ...
# 3  Python for beginners - Training | Microsoft Learn
# 4      Get started with Python in Visual Studio Code

# %%
df_2 = df2.to_csv()
df_2
# Out:
# ',Unnamed: 0,Unnamed: 1,Unnamed: 2\r\n0,,Python Learning Path,\r\n1,,#,Module\r\n2,,1,Introduction to Python - Training | Microsoft Learn\r\n3,,2,Python for beginners - Training | Microsoft Learn\r\n4,,3,Get started with Python in Visual Studio Code\r\n5,,4,Create and manage projects in Python\r\n6,,5,Numpy\r\n7,,6,Pandas\r\n8,,7,Scipy\r\n9,,8,File handling\r\n10,,9,Requests\r\n11,,10,Using GitHub Copilot with Python\r\n12,,11,Explore and analyze data with Python\r\n13,,12,Manage data with Python dictionaries\r\n14,,13,Get started with Jupyter notebooks for Python\r\n15,,14,Build an AI web app by using Python and Flask - Training | Microsoft Learn\r\n16,,15,Introduction to object-oriented programming with Python - Training | Microsoft Learn\r\n17,,16,Python error handling\r\n18,,17,Deploy a Django application to Azure by using PostgreSQL - Training | Microsoft Learn\r\n19,,18,Python Glossary\r\n'

# %%
print(df_2)
# Out:
# ,Unnamed: 0,Unnamed: 1,Unnamed: 2
# 0,,Python Learning Path,
# 1,,#,Module
# 2,,1,Introduction to Python - Training | Microsoft Learn
# 3,,2,Python for beginners - Training | Microsoft Learn
# 4,,3,Get started with Python in Visual Studio Code
# 5,,4,Create and manage projects in Python
# 6,,5,Numpy
# 7,,6,Pandas
# 8,,7,Scipy
# 9,,8,File handling
# 10,,9,Requests
# 11,,10,Using GitHub Copilot with Python
# 12,,11,Explore and analyze data with Python
# 13,,12,Manage data with Python dictionaries
# 14,,13,Get started with Jupyter notebooks for Python
# 15,,14,Build an AI web app by using Python and Flask - Training | Microsoft Learn
# 16,,15,Introduction to object-oriented programming with Python - Training | Microsoft Learn
# 17,,16,Python error handling
# 18,,17,Deploy a Django application to Azure by using PostgreSQL - Training | Microsoft Learn
# 19,,18,Python Glossary

# %%
# Read the CSV file into a pandas DataFrame
df_two = pd.read_csv(df_2)

df_two
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Read the CSV file into a pandas DataFrame
# ----> 2 df_two = pd.read_csv(df_2)
#       4 df_two
#
# ...
